# %%
import pandas as pd
import os

# %%
filepath = "C:\\Users\\steff\\Downloads\\acra-information-on-corporate-entities"
filename = "acra-information-on-corporate-entities-a.csv"
file = os.path.join(filepath, filename)

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#   business_constitution_description  \
# 0                   Sole Proprietor
# 1                   Sole Proprietor
# 2                   Sole Proprietor
# 3                   Sole Proprietor
# 4                   Sole Proprietor
#
#                             primary_ssic_description  \
# 0  REPAIR OF DOMESTIC ELECTRICAL/ELECTRONIC APPLI...
# 1    CHARTERED BUS SERVICES (INCLUDING SCHOOL BUSES)
# 2  MANAGEMENT CONSULTANCY SERVICES FOR HEALTHCARE...
# 3  LETTING AND OPERATING OF SELF-OWNED OR LEASED ...
# 4             MANAGEMENT CONSULTANCY SERVICES N.E.C.
#
#                      primary_user_described_activity            street_name  \
# 0                                                 na       HOUGANG AVENUE 8
# 1                                                 na       YISHUN STREET 41
# 2  PROVIDE BUSINESS MANAGEMENT AND CONSULTANCY SE...  BUKIT BATOK STREET 31
# 3                            SALES OF DRINKS & FOODS    TANJONG PAGAR PLAZA
# ...

# %%
list(df.columns)
# Out:
# ['business_constitution_description',
#  'primary_ssic_description',
#  'primary_user_described_activity',
#  'street_name',
#  'entity_status_description',
#  'annual_return_date',
#  'postal_code',
#  'paid_up_capital10_preference',
#  'entity_name',
#  'paid_up_capital2_others',
#  'name_of_audit_firm3',
#  'address_type',
#  'paid_up_capital9_currency',
#  'paid_up_capital8_ordinary',
#  'paid_up_capital6_others',
#  'paid_up_capital6_ordinary',
#  'level_no',
#  'paid_up_capital9_others',
#  'former_entity_name9',
#  'paid_up_capital7_currency',
#  'paid_up_capital6_preference',
#  'paid_up_capital4_currency',
#  'secondary_ssic_code',
#  'paid_up_capital7_preference',
#  'paid_up_capital1_preference',
#  'paid_up_capital2_preference',
#  'uen',
#  'uen_issue_date',
#  'no_of_officers',
#  'former_entity_name3',
#  'building_name',
#  'no_of_charges',
#  'paid_up_capital8_currency',
#  'paid_up_capital2_ordinary',
#  'paid_up_capital3_others',
#  'paid_up_capital4_others',
# ...

# %%
df.head()
# Out:
#   business_constitution_description  \
# 0                   Sole Proprietor
# 1                   Sole Proprietor
# 2                   Sole Proprietor
# 3                   Sole Proprietor
# 4                   Sole Proprietor
#
#                             primary_ssic_description  \
# 0  REPAIR OF DOMESTIC ELECTRICAL/ELECTRONIC APPLI...
# 1    CHARTERED BUS SERVICES (INCLUDING SCHOOL BUSES)
# 2  MANAGEMENT CONSULTANCY SERVICES FOR HEALTHCARE...
# 3  LETTING AND OPERATING OF SELF-OWNED OR LEASED ...
# 4             MANAGEMENT CONSULTANCY SERVICES N.E.C.
#
#                      primary_user_described_activity            street_name  \
# 0                                                 na       HOUGANG AVENUE 8
# 1                                                 na       YISHUN STREET 41
# 2  PROVIDE BUSINESS MANAGEMENT AND CONSULTANCY SE...  BUKIT BATOK STREET 31
# 3                            SALES OF DRINKS & FOODS    TANJONG PAGAR PLAZA
# ...

# %%
df[['entity_name', 
    'street_name', 
    'postal_code',
    'address_type',  
    'level_no', 
    'building_name', 
    'block',
    'other_address_line2',
    'other_address_line1',
    'unit_no']]
# Out:
#                                             entity_name  \
# 0                           A  & E ENGINEERING SERVICES
# 1                                        A  & Q TRANSIT
# 2                         A  AND Y CONSULTANCY SERVICES
# 3                                       A  COFFEE  SHOP
# 4                                 A  DIXIT & ASSOCIATES
# ...                                                 ...
# 137578                                         A_TALENT
# 137579                               A`VAIL HAIR STUDIO
# 137580                                       A|A DESIGN
# 137581  A~STAR PLASTIC LIGHT METAL INDUSTRIES PTE. LTD.
# 137582                        A~STAR PLASTICS PTE. LTD.
#
#                   street_name postal_code address_type level_no  \
# 0            HOUGANG AVENUE 8      530446        LOCAL       B1
# 1            YISHUN STREET 41      760456        LOCAL       06
# 2       BUKIT BATOK STREET 31      659443        LOCAL       09
# ...

# %%
df.shape
# Out:
# (137583, 94)
